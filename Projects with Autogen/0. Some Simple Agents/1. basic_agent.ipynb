# %%
# ---------------------------------------------------------------------------
# Imports: Core AutoGen components and utilities
# ---------------------------------------------------------------------------
import autogen
from autogen import AssistantAgent, UserProxyAgent
from pathlib import Path
from IPython.display import Image, Markdown
from dotenv import load_dotenv
import os

# %%
# Verify the installed AutoGen version (helps match tutorial and docs).
autogen.__version__
# Out:
# '0.10.4'

# %%
load_dotenv()  # Loads .env from the current directory (or parent directories)
# Out:
# True

# %%
# Step 2a: Load model configuration from CONFIG_LIST.json using the modern LLMConfig API.
# Keep this file out of source control; use .env or env vars for the actual API key.
llm_config_obj = autogen.LLMConfig.from_json(path="CONFIG_LIST.json")
config_list = llm_config_obj.config_list

# Optional: Filter config_list by model name
# Example: Filter to use only "llama-3.3-70b-versatile"
config_list = [config for config in config_list if config.get("model") == "llama-3.3-70b-versatile"]

# Or filter to use only "openai/gpt-oss-120b"
# config_list = [config for config in config_list if config.get("model") == "openai/gpt-oss-120b"]

# Or filter by partial model name match
# config_list = [config for config in config_list if "llama" in config.get("model", "").lower()]

# %%
# Step 2b: Create the AssistantAgent — the LLM-backed agent that will answer questions.
# - name: Used in conversation logs.
# - system_message: Instructions that shape the assistant’s behavior.
# - llm_config: Tells the agent which model(s) to use (from config_list).
assistant = AssistantAgent(
    name="groq_assistant",
    system_message="You are a helpful AI assistant specialized in explaining technical concepts clearly and concisely.",
    llm_config={
        "config_list": config_list,
        "temperature": 0.7  # Creativity level (0.0 to 1.0)
        },
    human_input_mode="NEVER" # No human intervention needed for this agent
)

# %%
# Step 3: Create the UserProxyAgent — represents the human user in the conversation.
# - code_execution_config=False: This example is Q&A only; no code will be run.
# - human_input_mode="NEVER": no prompts; proxy auto-replies so the chat runs unattended.
# - max_consecutive_auto_reply=1: stop after one assistant reply (avoids endless back-and-forth).

# Create the User Proxy (You)
user_proxy = UserProxyAgent(
    name="user_proxy",
    code_execution_config=False,  # We'll enable code execution in next section
    human_input_mode="NEVER",     # Automated chat for this example
    max_consecutive_auto_reply=1  # Limit conversation turns
)

# %%
# Step 4: Start the conversation. The user_proxy sends the first message to the assistant.
# The assistant replies; in this setup you may be prompted for input (e.g. type 'exit' to stop).
print("Initiating chat...")
user_proxy.initiate_chat(
    assistant,
    message="What are the key benefits of using AutoGen for building AI agents?")
# Out:
# Initiating chat...
# user_proxy (to groq_assistant):
#
# What are the key benefits of using AutoGen for building AI agents?
#
# --------------------------------------------------------------------------------
# groq_assistant (to user_proxy):
#
# AutoGen is a technology used for building AI agents, and its key benefits include:
#
# 1. **Rapid Development**: AutoGen enables rapid development of AI agents by automatically generating code, reducing the time and effort required to build and deploy AI models.
# 2. **Improved Efficiency**: AutoGen automates many tasks, such as data preprocessing, feature engineering, and hyperparameter tuning, making the development process more efficient and reducing the risk of human error.
# 3. **Increased Accuracy**: AutoGen can generate high-quality AI models by leveraging advanced machine learning algorithms and techniques, resulting in more accurate and reliable AI agents.
# 4. **Reduced Expertise Requirement**: AutoGen makes it possible for non-experts to build AI agents, as it provides a user-friendly interface and automated workflows that simplify the development process.
# 5. **Faster Iteration and Refining**: AutoGen allows for rapid iteration and refinement of AI models, enabling developers to quickly test and improve their models, and adapt to changing requirements.
# 6. **Scalability**: AutoGen can handle large datasets and complex AI models, making it suitable for building scalable AI agents that can handle real-world applications.
# 7. **Consistency and Reproducibility**: AutoGen ensures consistency and reproducibility of AI models, as it generates code and models using standardized workflows and algorithms.
# 8. **Reduced Maintenance**: AutoGen-generated AI agents require less maintenance, as the automated workflows and generated code reduce the need for manual updates and fixes.
#
# Overall, AutoGen simplifies the process of building AI agents, making it faster, more efficient, and more accessible to a wider range of developers, while also improving the accuracy and reliability of the resulting AI models.
#
# --------------------------------------------------------------------------------
# user_proxy (to groq_assistant):
#
#
#
# --------------------------------------------------------------------------------
# groq_assistant (to user_proxy):
#
# It seems like you didn't ask a question. Please go ahead and ask, and I'll do my best to provide a helpful and concise answer.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (6a02f0ed-afa9-486b-ac87-0e94464d9e3d): Maximum number of consecutive auto-replies reached
# ChatResult(chat_id=139104283653795004138777418805404791104, chat_history=[{'content': 'What are the key benefits of using AutoGen for building AI agents?', 'role': 'assistant', 'name': 'user_proxy'}, {'content': 'AutoGen is a technology used for building AI agents, and its key benefits include:\n\n1. **Rapid Development**: AutoGen enables rapid development of AI agents by automatically generating code, reducing the time and effort required to build and deploy AI models.\n2. **Improved Efficiency**: AutoGen automates many tasks, such as data preprocessing, feature engineering, and hyperparameter tuning, making the development process more efficient and reducing the risk of human error.\n3. **Increased Accuracy**: AutoGen can generate high-quality AI models by leveraging advanced machine learning algorithms and techniques, resulting in more accurate and reliable AI agents.\n4. **Reduced Expertise Requirement**: AutoGen makes it possible for non-experts to build AI agents, as it provides a user-friendly interface and automated workflows that simplify the development process.\n5. **Faster Iteration and Refining**: AutoGen allows for rapid iteration and refinement of AI models, enabling developers to quickly test and improve their models, and adapt to changing requirements.\n6. **Scalability**: AutoGen can handle large datasets and complex AI models, making it suitable for building scalable AI agents that can handle real-world applications.\n7. **Consistency and Reproducibility**: AutoGen ensures consistency and reproducibility of AI models, as it generates code and models using standardized workflows and algorithms.\n8. **Reduced Maintenance**: AutoGen-generated AI agents require less maintenance, as the automated workflows and generated code reduce the need for manual updates and fixes.\n\nOverall, AutoGen simplifies the process of building AI agents, making it faster, more efficient, and more accessible to a wider range of developers, while also improving the accuracy and reliability of the resulting AI models.', 'role': 'user', 'name': 'groq_assistant'}, {'content': '', 'role': 'assistant', 'name': 'user_proxy'}, {'content': "It seems like you didn't ask a question. Please go ahead and ask, and I'll do my best to provide a helpful and concise answer.", 'role': 'user', 'name': 'groq_assistant'}], summary="It seems like you didn't ask a question. Please go ahead and ask, and I'll do my best to provide a helpful and concise answer.", cost={'usage_including_cached_inference': {'total_cost': 0.0, 'llama-3.3-70b-versatile': {'cost': 0.0, 'prompt_tokens': 12693, 'completion_tokens': 4020, 'total_tokens': 16713}}, 'usage_excluding_cached_inference': {'total_cost': 0.0, 'llama-3.3-70b-versatile': {'cost': 0.0, 'prompt_tokens': 12693, 'completion_tokens': 4020, 'total_tokens': 16713}}}, human_input=[])
